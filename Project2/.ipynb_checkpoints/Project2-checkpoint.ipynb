# %% [markdown]
# # Исследование объявлений о продаже квартир

# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Цель-проекта:" data-toc-modified-id="Цель-проекта:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Цель проекта:</a></span></li><li><span><a href="#План-проекта:" data-toc-modified-id="План-проекта:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>План проекта:</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Знакомство-с-данными" data-toc-modified-id="Знакомство-с-данными-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Знакомство с данными</a></span><ul class="toc-item"><li><span><a href="#total_images" data-toc-modified-id="total_images-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>total_images</a></span></li><li><span><a href="#last_price" data-toc-modified-id="last_price-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>last_price</a></span></li><li><span><a href="#total_area" data-toc-modified-id="total_area-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>total_area</a></span></li><li><span><a href="#first_day_exposition" data-toc-modified-id="first_day_exposition-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>first_day_exposition</a></span></li><li><span><a href="#rooms" data-toc-modified-id="rooms-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>rooms</a></span></li><li><span><a href="#ceiling_height" data-toc-modified-id="ceiling_height-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>ceiling_height</a></span></li><li><span><a href="#floors_total" data-toc-modified-id="floors_total-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>floors_total</a></span></li><li><span><a href="#living_area" data-toc-modified-id="living_area-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>living_area</a></span></li><li><span><a href="#floor" data-toc-modified-id="floor-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>floor</a></span></li><li><span><a href="#is_apartment" data-toc-modified-id="is_apartment-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>is_apartment</a></span></li><li><span><a href="#studio" data-toc-modified-id="studio-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>studio</a></span></li><li><span><a href="#open_plan" data-toc-modified-id="open_plan-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>open_plan</a></span></li><li><span><a href="#kitchen_area" data-toc-modified-id="kitchen_area-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>kitchen_area</a></span></li><li><span><a href="#balcony" data-toc-modified-id="balcony-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>balcony</a></span></li><li><span><a href="#locality_name" data-toc-modified-id="locality_name-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>locality_name</a></span></li><li><span><a href="#airports_nearest" data-toc-modified-id="airports_nearest-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>airports_nearest</a></span></li><li><span><a href="#citycenters_nearest" data-toc-modified-id="citycenters_nearest-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>citycenters_nearest</a></span></li><li><span><a href="#parks_around3000" data-toc-modified-id="parks_around3000-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>parks_around3000</a></span></li><li><span><a href="#parks_nearest" data-toc-modified-id="parks_nearest-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>parks_nearest</a></span></li><li><span><a href="#ponds_around3000" data-toc-modified-id="ponds_around3000-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>ponds_around3000</a></span></li><li><span><a href="#ponds_nearest" data-toc-modified-id="ponds_nearest-2.21"><span class="toc-item-num">2.21&nbsp;&nbsp;</span>ponds_nearest</a></span></li><li><span><a href="#days_exposition" data-toc-modified-id="days_exposition-2.22"><span class="toc-item-num">2.22&nbsp;&nbsp;</span>days_exposition</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-2.23"><span class="toc-item-num">2.23&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#first_day_exposition" data-toc-modified-id="first_day_exposition-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>first_day_exposition</a></span></li><li><span><a href="#last_price" data-toc-modified-id="last_price-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>last_price</a></span></li><li><span><a href="#balcony" data-toc-modified-id="balcony-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>balcony</a></span></li><li><span><a href="#rooms" data-toc-modified-id="rooms-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>rooms</a></span></li><li><span><a href="#ceiling_height" data-toc-modified-id="ceiling_height-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>ceiling_height</a></span></li><li><span><a href="#floors_total" data-toc-modified-id="floors_total-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>floors_total</a></span></li><li><span><a href="#living_area" data-toc-modified-id="living_area-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>living_area</a></span></li><li><span><a href="#is_apartment" data-toc-modified-id="is_apartment-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>is_apartment</a></span></li><li><span><a href="#locality_name" data-toc-modified-id="locality_name-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>locality_name</a></span></li><li><span><a href="#airports_nearest" data-toc-modified-id="airports_nearest-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>airports_nearest</a></span></li><li><span><a href="#citycenters_nearest" data-toc-modified-id="citycenters_nearest-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>citycenters_nearest</a></span></li><li><span><a href="#parks_around3000" data-toc-modified-id="parks_around3000-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>parks_around3000</a></span></li><li><span><a href="#ponds_around3000" data-toc-modified-id="ponds_around3000-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>ponds_around3000</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Вычисления-и-добавление-в-таблицу" data-toc-modified-id="Вычисления-и-добавление-в-таблицу-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вычисления и добавление в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления;" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления;-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления;</a></span></li><li><span><a href="#Этаж-квартиры;-варианты-—-первый,-последний,-другой;" data-toc-modified-id="Этаж-квартиры;-варианты-—-первый,-последний,-другой;-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Этаж квартиры; варианты — первый, последний, другой;</a></span></li><li><span><a href="#Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей." data-toc-modified-id="Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Соотношение жилой и общей площади, а также отношение площади кухни к общей.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучить-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков" data-toc-modified-id="Изучить-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Изучить следующие параметры: площадь, цена, число комнат, высота потолков</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Площадь</a></span></li><li><span><a href="#Цена" data-toc-modified-id="Цена-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Цена</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li></ul></li><li><span><a href="#Изучить-время-продажи-квартиры." data-toc-modified-id="Изучить-время-продажи-квартиры.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Изучить время продажи квартиры.</a></span></li><li><span><a href="#Убрать-редкие-и-выбивающиеся-значения.-Выделить-особенности." data-toc-modified-id="Убрать-редкие-и-выбивающиеся-значения.-Выделить-особенности.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Убрать редкие и выбивающиеся значения. Выделить особенности.</a></span><ul class="toc-item"><li><span><a href="#Общая-площадь" data-toc-modified-id="Общая-площадь-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Общая площадь</a></span></li><li><span><a href="#Цена-квартиры" data-toc-modified-id="Цена-квартиры-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Цена квартиры</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Высота потолков</a></span></li><li><span><a href="#Цена-за-квадратный-метр" data-toc-modified-id="Цена-за-квадратный-метр-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Цена за квадратный метр</a></span></li></ul></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры?</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выделить-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья." data-toc-modified-id="Выделить-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Выделить населённые пункты с самой высокой и низкой стоимостью жилья.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выяснить,-какая-область-входит-в-центр." data-toc-modified-id="Выяснить,-какая-область-входит-в-центр.-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Выяснить, какая область входит в центр.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выделить-факторы,-которые-влияют-на-стоимость-квартиры-в-центре" data-toc-modified-id="Выделить-факторы,-которые-влияют-на-стоимость-квартиры-в-центре-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Выделить факторы, которые влияют на стоимость квартиры в центре</a></span><ul class="toc-item"><li><span><a href="#Выделяем-квартиры-в-центре" data-toc-modified-id="Выделяем-квартиры-в-центре-5.7.1"><span class="toc-item-num">5.7.1&nbsp;&nbsp;</span>Выделяем квартиры в центре</a></span></li><li><span><a href="#Анализ-территории-по-параметрам:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Анализ-территории-по-параметрам:-площадь,-цена,-число-комнат,-высота-потолков.-5.7.2"><span class="toc-item-num">5.7.2&nbsp;&nbsp;</span>Анализ территории по параметрам: площадь, цена, число комнат, высота потолков.</a></span></li><li><span><a href="#Анализ-факторов,-которые-влияют-на-стоимость-квартиры" data-toc-modified-id="Анализ-факторов,-которые-влияют-на-стоимость-квартиры-5.7.3"><span class="toc-item-num">5.7.3&nbsp;&nbsp;</span>Анализ факторов, которые влияют на стоимость квартиры</a></span></li><li><span><a href="#Сравнение-между-городом-и-его-центром" data-toc-modified-id="Сравнение-между-городом-и-его-центром-5.7.4"><span class="toc-item-num">5.7.4&nbsp;&nbsp;</span>Сравнение между городом и его центром</a></span><ul class="toc-item"><li><span><a href="#Центр-города" data-toc-modified-id="Центр-города-5.7.4.1"><span class="toc-item-num">5.7.4.1&nbsp;&nbsp;</span>Центр города</a></span></li><li><span><a href="#Город" data-toc-modified-id="Город-5.7.4.2"><span class="toc-item-num">5.7.4.2&nbsp;&nbsp;</span>Город</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.7.5"><span class="toc-item-num">5.7.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# В моем распоряжении архив объявлений о продаже квартире в Санкт-Петербурге и соседних нас. пунктах. Нужно написать код для автоматизированной системы, которая отслеживает аномалии.

# %% [markdown]
# ### Цель проекта:

# %% [markdown]
# Что необходимо сделать:
#  - Изучить следующие параметры: площадь, цена, число комнат, высота потолков
#  - Изучить время продажи квартиры.
#  - Убрать редкие и выбивающиеся значения. Выделить особенности.
#  - Какие факторы больше всего влияют на стоимость квартиры?
#  - Выделить населённые пункты с самой высокой и низкой стоимостью жилья.
#  - Выяснить, какая область входит в центр.
#  - Выделить факторы, которые влияют на стоимость квартиры в центре

# %% [markdown]
# ### План проекта:

# %% [markdown]
#  -  Знакомство с данными
#  -  Предобработка данных
#  -  Вычисления и добавление в таблицу
#  -  Исследовательский анализ данных
#  -  Общий вывод

# %% [markdown]
# ## Знакомство с данными

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('/datasets/real_estate_data.csv')

# %%
data
# Out:
#       total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0      20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1      7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2      10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3      0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4      2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...
# ...                                                  ...
# 23694  9\t9700000.0\t133.81\t2017-03-21T00:00:00\t3\t...
# 23695  14\t3100000.0\t59.0\t2018-01-15T00:00:00\t3\t\...
# 23696  18\t2500000.0\t56.7\t2018-02-11T00:00:00\t2\t\...
# 23697  13\t11475000.0\t76.75\t2017-03-28T00:00:00\t2\...
# 23698  4\t1350000.0\t32.3\t2017-07-21T00:00:00\t1\t2....
#
# [23699 rows x 1 columns]

# %% [markdown]
# Видим, что данные не читабельные. Сделаем их в привычном для нас виде.

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Теперь данные читабельные.
# Пройдемся по столбцам.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### total_images

# %% [markdown]
# ### last_price

# %% [markdown]
# Нужно поменять тип данных

# %% [markdown]
# ### total_area

# %%
data.total_area.head(20)
# Out:
# 0     108.00
# 1      40.40
# 2      56.00
# 3     159.00
# 4     100.00
# 5      30.40
# 6      37.30
# 7      71.60
# 8      33.16
# 9      61.00
# 10     39.60
# 11     44.00
# 12     54.00
# 13     42.80
# 14     36.00
# 15     39.00
# 16     82.00
# 17     36.00
# 18     31.00
# 19    121.00
# Name: total_area, dtype: float64

# %% [markdown]
# ### first_day_exposition

# %%
data.first_day_exposition.value_counts()
# Out:
# 2018-02-01T00:00:00    368
# 2017-11-10T00:00:00    240
# 2017-10-13T00:00:00    124
# 2017-09-27T00:00:00    111
# 2018-03-26T00:00:00     97
#                       ...
# 2016-07-22T00:00:00      1
# 2015-09-17T00:00:00      1
# 2015-04-04T00:00:00      1
# 2018-04-14T00:00:00      1
# 2015-05-05T00:00:00      1
# Name: first_day_exposition, Length: 1491, dtype: int64

# %% [markdown]
# Уберем время

# %% [markdown]
# ### rooms

# %%
data['rooms'].value_counts()
# Out:
# 1     8047
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 0      197
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 14       2
# 11       2
# 19       1
# 12       1
# 16       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
#  Видим, что данные в этом столбце не совсем корректны, необходимо разобраться с этим

# %% [markdown]
# ### ceiling_height

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.ceiling_height.describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Видим и понимаем, что высота потолка не может быть 100 метров или 1 метр, нужно так же с этим разобраться. И с нанами тоже, видимо просто не указали высоту потолков.

# %% [markdown]
# ### floors_total

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# На первый взгляд все нормально, кроме того, что присутствуют наны. Надо тип данных поменять на инт. Посмотрим, что будет дальше

# %% [markdown]
# ### living_area

# %%
data.living_area.describe()
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Есть пропуски в данных

# %% [markdown]
# ### floor

# %%
data.floor.value_counts()
# Out:
# 2     3368
# 3     3073
# 1     2917
# 4     2804
# 5     2621
# 6     1305
# 7     1218
# 8     1083
# 9     1051
# 10     687
# 12     526
# 11     523
# 13     379
# 15     343
# 14     337
# 16     315
# 17     227
# 18     178
# 19     147
# 21     125
# 22     113
# 20     110
# 23     100
# 24      63
# 25      46
# 26      24
# 27      10
# 28       1
# 33       1
# 29       1
# 30       1
# 32       1
# 31       1
# Name: floor, dtype: int64

# %% [markdown]
# Здесь все хорошо

# %% [markdown]
# ### is_apartment

# %%
data['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Не хватает данных, возможно наны

# %% [markdown]
# ### studio

# %%
data.studio.value_counts()
# Out:
# False    23550
# True       149
# Name: studio, dtype: int64

# %% [markdown]
# ТОже все хорошо

# %% [markdown]
# ### open_plan

# %%
data.open_plan.value_counts()
# Out:
# False    23632
# True        67
# Name: open_plan, dtype: int64

# %% [markdown]
# ### kitchen_area

# %%
data.kitchen_area.describe()
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Кухня в 112 кв. метров? Многовато что то, но нужно будет проверить, как и кухню в 1 кв. м.

# %% [markdown]
# ### balcony

# %%
data.balcony.value_counts()
# Out:
# 1.0    4195
# 0.0    3758
# 2.0    3659
# 5.0     304
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64

# %% [markdown]
#  Много нанов, можно предположить, что если пропуск, то его просто не заполнили, значит можем заменить наны на 0

# %% [markdown]
# ### locality_name

# %%
data.locality_name.value_counts()
# Out:
# Санкт-Петербург                 15721
# посёлок Мурино                    522
# посёлок Шушары                    440
# Всеволожск                        398
# Пушкин                            369
#                                 ...
# поселок Сумино                      1
# поселок Жилпосёлок                  1
# посёлок Мыза-Ивановка               1
# поселок Володарское                 1
# городской посёлок Свирьстрой        1
# Name: locality_name, Length: 364, dtype: int64

# %% [markdown]
# Присутствуют наны

# %% [markdown]
# ### airports_nearest

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.airports_nearest
# Out:
# 0        18863.0
# 1        12817.0
# 2        21741.0
# 3        28098.0
# 4        31856.0
#           ...
# 23694    24665.0
# 23695        NaN
# 23696        NaN
# 23697    39140.0
# 23698        NaN
# Name: airports_nearest, Length: 23699, dtype: float64

# %% [markdown]
# Присутвуют наны, оставим их как есть, чтобы не искажать данные

# %% [markdown]
# ### citycenters_nearest

# %%
data.cityCenters_nearest.value_counts()
# Out:
# 8460.0     61
# 20802.0    32
# 10720.0    30
# 8434.0     27
# 20444.0    27
#            ..
# 13104.0     1
# 11280.0     1
# 27218.0     1
# 10501.0     1
# 208.0       1
# Name: cityCenters_nearest, Length: 7642, dtype: int64

# %% [markdown]
# Много пропусков, но оставим их, чтобы не искажать данные, не сможем точно заменить их

# %% [markdown]
# ###  parks_around3000

# %%
data.parks_around3000
# Out:
# 0        1.0
# 1        0.0
# 2        1.0
# 3        2.0
# 4        2.0
#         ...
# 23694    1.0
# 23695    NaN
# 23696    NaN
# 23697    2.0
# 23698    NaN
# Name: parks_around3000, Length: 23699, dtype: float64

# %% [markdown]
# Предположим если есть пропуски, то их просто не заполняли, поэтому заменим их на 0

# %% [markdown]
# ### parks_nearest

# %%
data.parks_nearest
# Out:
# 0        482.0
# 1          NaN
# 2         90.0
# 3         84.0
# 4        112.0
#          ...
# 23694    796.0
# 23695      NaN
# 23696      NaN
# 23697    173.0
# 23698      NaN
# Name: parks_nearest, Length: 23699, dtype: float64

# %% [markdown]
# Пропуски не будем трогать, не сможем их заменить на точные данные

# %% [markdown]
# ### ponds_around3000

# %%
data.ponds_around3000
# Out:
# 0        2.0
# 1        0.0
# 2        2.0
# 3        3.0
# 4        1.0
#         ...
# 23694    3.0
# 23695    NaN
# 23696    NaN
# 23697    3.0
# 23698    NaN
# Name: ponds_around3000, Length: 23699, dtype: float64

# %% [markdown]
# Можно считать, если есть пропуски, то просто их не заполняли, поэтому можно заменить на 0

# %% [markdown]
# ### ponds_nearest

# %%
data.ponds_nearest
# Out:
# 0        755.0
# 1          NaN
# 2        574.0
# 3        234.0
# 4         48.0
#          ...
# 23694    381.0
# 23695      NaN
# 23696      NaN
# 23697    196.0
# 23698      NaN
# Name: ponds_nearest, Length: 23699, dtype: float64

# %% [markdown]
# Пропуски не будем трогать, не сможем их заменить на точные данные

# %% [markdown]
# ### days_exposition

# %%
data.days_exposition
# Out:
# 0          NaN
# 1         81.0
# 2        558.0
# 3        424.0
# 4        121.0
#          ...
# 23694      NaN
# 23695     45.0
# 23696      NaN
# 23697    602.0
# 23698      NaN
# Name: days_exposition, Length: 23699, dtype: float64

# %%
data.days_exposition.describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# ЗАменим тип данных. Так же есть пропуски. Пропуски не будем трогать, не сможем их заменить на точные данные

# %% [markdown]
# ### Вывод:

# %% [markdown]
# Познакомились с данными, и нужно их привести в другой вид, чтобы дальше работать с ними

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Приступим к предобработке данных

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# ### first_day_exposition

# %% [markdown]
# Меняем тип данных

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'])

# %% [markdown]
# ### last_price

# %% [markdown]
# Заменим тип данных

# %%
data.last_price = data.last_price.astype('int')

# %% [markdown]
# ### balcony

# %%
data['balcony'].fillna(0, inplace=True)

# %% [markdown]
# Теперь пропущенных значений нет. Изменим тип данных

# %%
data.balcony = data.balcony.astype('int')

# %% [markdown]
# ### rooms

# %%
data['rooms'].value_counts()
# Out:
# 1     8047
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 0      197
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 14       2
# 11       2
# 19       1
# 12       1
# 16       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
# Тут предобработка не нужна. Большое количество комнат - скорее всего это элитный дом

# %% [markdown]
# ### ceiling_height

# %%
data.ceiling_height.value_counts()
# Out:
# 2.50      3515
# 2.60      1646
# 2.70      1574
# 3.00      1112
# 2.80       993
#           ...
# 27.50        1
# 5.00         1
# 3.59         1
# 4.80         1
# 100.00       1
# Name: ceiling_height, Length: 183, dtype: int64

# %% [markdown]
# При построении графиков высоту потолка в 100 метров или 1 метр мы просто проигнорируем. С пропусками мы ничего не можем сделать.

# %% [markdown]
# ### floors_total

# %% [markdown]
# Так же как с высотой потолков, пропуски не можем заменить

# %% [markdown]
# ### living_area

# %% [markdown]
# Маленькую площадь мы просто проигнорируем. Большую будем считать, что дом элитный и это реальные данные

# %% [markdown]
# ### is_apartment

# %% [markdown]
# Здесь будем считать, что если пропуски, то просто не указали эти данные. Оставим как есть

# %% [markdown]
# ### locality_name

# %% [markdown]
# Здесь ничего не сможешь сделать с пропусками.

# %% [markdown]
# ### airports_nearest

# %% [markdown]
# Не будем искажать данные

# %% [markdown]
# ### citycenters_nearest

# %% [markdown]
# Не будем искажать данные

# %% [markdown]
# ###  parks_around3000

# %% [markdown]
# Заменим пропуски на 0

# %%
data['parks_around3000'].fillna(0)
# Out:
# 0        1.0
# 1        0.0
# 2        1.0
# 3        2.0
# 4        2.0
#         ...
# 23694    1.0
# 23695    0.0
# 23696    0.0
# 23697    2.0
# 23698    0.0
# Name: parks_around3000, Length: 23699, dtype: float64

# %% [markdown]
# ### ponds_around3000

# %% [markdown]
# Заменим пропуски на 0

# %%
data['ponds_around3000'].fillna(0)
# Out:
# 0        2.0
# 1        0.0
# 2        2.0
# 3        3.0
# 4        1.0
#         ...
# 23694    3.0
# 23695    0.0
# 23696    0.0
# 23697    3.0
# 23698    0.0
# Name: ponds_around3000, Length: 23699, dtype: float64

# %% [markdown]
# ### Вывод:

# %% [markdown]
# Поправил немного данные, где посчитал нужным и возможным заменил пропуски.

# %% [markdown]
# ## Вычисления и добавление в таблицу

# %% [markdown]
# ### Цена квадратного метра

# %%
data['price_per_qm'] = data['last_price'] / data['total_area']

# %%
data['price_per_qm'] = data['price_per_qm'].round().astype('int')

# %% [markdown]
# ### День недели, месяц и год публикации объявления;

# %% [markdown]
# Разделим дату на день недели, месяц и год

# %%
data['day_of_week'] = data['first_day_exposition'].dt.weekday

# %%
data.dtypes
# Out:
# total_images                     int64
# last_price                       int64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                   float64
# living_area                    float64
# floor                            int64
# is_apartment                    object
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int64
# locality_name                   object
# airports_nearest               float64
# cityCenters_nearest            float64
# parks_around3000               float64
# parks_nearest                  float64
# ponds_around3000               float64
# ponds_nearest                  float64
# days_exposition                float64
# price_per_qm                     int64
# day_of_week                      int64
# dtype: object

# %%
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year

# %%
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month

# %% [markdown]
# ### Этаж квартиры; варианты — первый, последний, другой;

# %% [markdown]
# Напишем функцию, чтобы распределить этажи.

# %%
def fillfloor(row):
    if row['floor'] == 1:
        return 'Первый'
    if row['floor'] == row['floors_total']:
        return 'Последний'
    else: 
        return 'Другой'
data['floors_group'] = data.apply(fillfloor, axis = 1)

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 4                 2    10000000      100.00           2018-06-19      2
# 5                10     2890000       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9     4600000       62.40           2016-08-05      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# ### Соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# Соотношение жилой и общей площади

# %%
data['living_total_area'] = data['living_area'] / data['total_area']

# %%
data['living_total_area']
# Out:
# 0        0.472222
# 1        0.460396
# 2        0.612500
# 3             NaN
# 4        0.320000
#            ...
# 23694    0.547792
# 23695    0.644068
# 23696    0.523810
# 23697         NaN
# 23698    0.380805
# Name: living_total_area, Length: 23699, dtype: float64

# %% [markdown]
# Отношение площади кухни к общей

# %%
data['kitchen_total'] = data['kitchen_area'] / data['total_area']

# %%
data['kitchen_total'] = data['kitchen_total'].round(2)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Добавили новые вычисления в таблицу, чтобы в дальнейшем ответить на интересующие нас вопросы.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучить следующие параметры: площадь, цена, число комнат, высота потолков

# %% [markdown]
# #### Площадь

# %%
data.total_area.value_counts()
# Out:
# 45.00     419
# 42.00     383
# 60.00     347
# 31.00     346
# 44.00     345
#          ...
# 45.85       1
# 44.18       1
# 59.83       1
# 127.20      1
# 23.55       1
# Name: total_area, Length: 2182, dtype: int64

# %%
data['total_area'].plot(kind='hist', legend=True, grid=True, title = 'Площадь',bins=(50), range=(10, 230))
plt.xlabel('total_area')
# Out:
# Text(0.5, 0, 'total_area')

# %% [markdown]
# По графику видно, что в основном продаются квартиры с площадью от 30 м2 до 60 м2

# %% [markdown]
# #### Цена

# %%
data['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
data['last_price'].plot(kind='hist', legend=True, grid=True,
                        title = 'Цены квартир',range=(0,10000000),bins=(50))
plt.xlabel('last_price')
# Out:
# Text(0.5, 0, 'last_price')

# %% [markdown]
# По графику видно, что в основном квартиры продаются в интервале от 3.5 млн до 4.5 млн рублей

# %% [markdown]
# #### Число комнат

# %%
data['rooms'].value_counts()
# Out:
# 1     8047
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 0      197
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 14       2
# 11       2
# 19       1
# 12       1
# 16       1
# 15       1
# Name: rooms, dtype: int64

# %%
data['rooms'].plot(kind='hist', legend=True, grid=True, title = 'Количество комнат',
                   range=(1,7), bins=(10))
plt.xlabel('rooms')
# Out:
# Text(0.5, 0, 'rooms')

# %% [markdown]
# Больше всего количество продаж однокомнатных, двухкомнатных квартир. Квартиры/ дома с большим количеством комнат, решил не включать с график, чтобы построился точнее

# %% [markdown]
# #### Высота потолков

# %%
data['ceiling_height'].value_counts()
# Out:
# 2.50      3515
# 2.60      1646
# 2.70      1574
# 3.00      1112
# 2.80       993
#           ...
# 27.50        1
# 5.00         1
# 3.59         1
# 4.80         1
# 100.00       1
# Name: ceiling_height, Length: 183, dtype: int64

# %%
data['ceiling_height'].plot(kind='hist', title = 'Высота потолков', legend=True, 
                            grid=True, range=(2,5), bins=(20)) 
plt.xlabel('ceiling_height')
# Out:
# Text(0.5, 0, 'ceiling_height')

# %% [markdown]
# Высота потолков в основном варьируется от 2.5 до 3 м

# %% [markdown]
# ### Изучить время продажи квартиры.

# %%
data['days_exposition'].plot(kind='hist', title = 'Время продажи квартиры',
                             legend=True, grid=True, bins=(20))
plt.xlabel('days_exposition')
# Out:
# Text(0.5, 0, 'days_exposition')

# %%
data.days_exposition.mean()
# Out:
# 180.88863436982163

# %%
data.days_exposition.median()
# Out:
# 95.0

# %%
data.days_exposition.describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# В среднем продажи продаются за 95 дней

# %% [markdown]
# В нашем случае продажа прошла очень быстро - 1 день.
# Очень медленно - 1580 дней.

# %% [markdown]
# ### Убрать редкие и выбивающиеся значения. Выделить особенности.

# %% [markdown]
# #### Общая площадь

# %%
data['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
data.boxplot(column=['total_area'])

# %%
Q1 = data['total_area'].quantile(0.25)
Q3 = data['total_area'].quantile(0.75)
IQR = Q3 - Q1
data = data.drop(data[data.total_area > Q3+1.5*IQR].index)
data = data.drop(data[data.total_area < Q1-1.5*IQR].index)

# %%
data.boxplot(column=['total_area'])

# %% [markdown]
# Чтобы большие площади не портили статистику мы их уберем. Площадь квартиры 114 метров мне кажется больше нам подходит

# %% [markdown]
# #### Цена квартиры

# %%
data.boxplot(column=['last_price'])

# %%
Q1 = data['last_price'].quantile(0.15)
Q3 = data['last_price'].quantile(0.85)
IQR = Q3 - Q1
data = data.drop(data[data.last_price > Q3+1.5*IQR].index)
data = data.drop(data[data.last_price < Q1-1.5*IQR].index)

# %%
data['last_price'].describe()
# Out:
# count    2.209100e+04
# mean     5.043776e+06
# std      2.571363e+06
# min      1.219000e+04
# 25%      3.350000e+06
# 50%      4.495000e+06
# 75%      6.178822e+06
# max      1.500000e+07
# Name: last_price, dtype: float64

# %%
data.boxplot(column=['last_price'])

# %% [markdown]
# Цена 76 млн может и реальна, но редкая она, поэтому убераем ее. Квартира за 17 млн, ближе к общей массе

# %% [markdown]
# #### Высота потолков

# %%
data.boxplot(column=['ceiling_height'])

# %%
Q1 = data['ceiling_height'].quantile(0.25)
Q3 = data['ceiling_height'].quantile(0.75)
IQR = Q3 - Q1
data = data.drop(data[data.ceiling_height > Q3+1.5*IQR].index)
data = data.drop(data[data.ceiling_height < Q1-1.5*IQR].index)

# %% [markdown]
# Я считаю, что высота потолков больше 3,5 метров это уже выброс, но вдруг в элитных домах потолки и по 4 метра

# %% [markdown]
# #### Цена за квадратный метр

# %%
data.boxplot(column=['price_per_qm'])

# %%
Q1 = data['price_per_qm'].quantile(0.25)
Q3 = data['price_per_qm'].quantile(0.75)
IQR = Q3 - Q1
data = data.drop(data[data.price_per_qm > Q3+1.5*IQR].index)
data = data.drop(data[data.price_per_qm < Q1-1.5*IQR].index)

# %%
data.boxplot(column=['price_per_qm'])

# %% [markdown]
# Есть значения больше 200 000 рублей за квадратный метр. Уберем их, чтобы не выбивались из общей массы.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры?

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 4                 2    10000000      100.00           2018-06-19      2
# 5                10     2890000       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9     4600000       62.40           2016-08-05      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
pearsoncorr = data.assign(floors_group=data.floors_group.astype('category').cat.codes).corr()
plt.figure(figsize = (20,10))
sb.heatmap(pearsoncorr,annot = True,linewidths=.5,cmap="YlGnBu")

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 4                 2    10000000      100.00           2018-06-19      2
# 5                10     2890000       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9     4600000       62.40           2016-08-05      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
list_of_vars2 = ['total_area','rooms','cityCenters_nearest','floor','year','month','day_of_week']

# %%
for var in list_of_vars2:
    ax = data.plot(x = var, y = 'last_price',style = 'o',title = 'Зависимость last_price от '+var,alpha = 0.3)
    ax.set_ylabel("last_price")
    plt.show()

# %% [markdown]
# #### Вывод

# %% [markdown]
# По графикам видно, что:
#  - зависимость между ценой и общей площадью прямая, коэффициент корреляции Пирсона = 0.75;
#  - зависимость между ценой и количеством комнат есть, коэффициент корреляции Пирсона = 0.47;
#  - зависимость между ценой и расстоянием до центра есть, коэффициент корреляции Пирсона =   -0.31;
#  - зависимости между ценой и этажами практически нет, коэффициент корреляции Пирсона = 0.15;
#  - зависимости между ценой и годом нет, коэффициент корреляции Пирсона = -0.0034;
#  - зависимости между ценой и месяцем нет, коэффициент корреляции Пирсона = 0.0063;
#  - зависимости между ценой и днем недели нет, коэффициент корреляции Пирсона = -0.005;

# %%
data_median = data.pivot_table(index='floors_group', values= 'last_price', aggfunc='median')

# %%
data_median.plot(title = 'Зависимость last_price от floors_group', grid=True)
plt.ylabel('last_price')
# Out:
# Text(0, 0.5, 'last_price')

# %% [markdown]
# ### Выделить населённые пункты с самой высокой и низкой стоимостью жилья.

# %% [markdown]
# Создаем новую таблицу с населенными пунктами

# %%
city_top10 = data['locality_name'].value_counts().head(10).index.tolist()

# %%
city_top10
# Out:
# ['Санкт-Петербург',
#  'посёлок Мурино',
#  'посёлок Шушары',
#  'Всеволожск',
#  'Пушкин',
#  'Колпино',
#  'посёлок Парголово',
#  'деревня Кудрово',
#  'Гатчина',
#  'Выборг']

# %%
data_city_top10 = data[data['locality_name'].isin(city_top10)]

# %% [markdown]
# Находим среднюю цену за квадрат в населенных пунктах

# %%
city_mean_ppq = data_city_top10.pivot_table(index='locality_name', values='price_per_qm', aggfunc ='mean')

# %%
city_mean_ppq.sort_values(by='price_per_qm')
# Out:
#                     price_per_qm
# locality_name
# Выборг              58160.384977
# Всеволожск          67161.687179
# Гатчина             69216.919463
# Колпино             75458.917683
# посёлок Шушары      78682.555046
# посёлок Мурино      85725.234615
# посёлок Парголово   90332.236196
# деревня Кудрово     92409.768456
# Пушкин             100863.312121
# Санкт-Петербург    104947.574008

# %% [markdown]
# #### Вывод

# %% [markdown]
# Самая низкая стоимость за квадратный метр в Выборге. А самая высокая в Питере.

# %% [markdown]
# ### Выяснить, какая область входит в центр.

# %% [markdown]
# Делаем таблицу только для Питера.

# %%
spb = data.query('locality_name == "Санкт-Петербург"')

# %%
spb['centr_nearest_km'] = spb['cityCenters_nearest'] / 1000
# Out:
# <ipython-input-89-08e350514718>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spb['centr_nearest_km'] = spb['cityCenters_nearest'] / 1000

# %%
spb_good = spb[['locality_name', 'last_price', 'centr_nearest_km']]

# %%
spb_good['centr_nearest_km'] = spb_good['centr_nearest_km'].round()
# Out:
# <ipython-input-91-2906fbf06e16>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spb_good['centr_nearest_km'] = spb_good['centr_nearest_km'].round()

# %% [markdown]
# Считаем среднюю цену за квартиру по километрам

# %%
spb_good.pivot_table(index= 'centr_nearest_km', values = 'last_price', 
                     aggfunc='mean').plot(title = 
                     'Зависимость стоимости и удаленности от центра', grid = True)

# %% [markdown]
# #### Вывод

# %% [markdown]
# Центральная зона до 5 км

# %% [markdown]
# ### Выделить факторы, которые влияют на стоимость квартиры в центре

# %% [markdown]
# #### Выделяем квартиры в центре

# %%
data_centre = data[['total_area','last_price', 'floor',
                    'rooms', 'ceiling_height', 'cityCenters_nearest', 'first_day_exposition','year','month','day_of_week']]

# %%
data_centre_good = data_centre.query('cityCenters_nearest < 5000')

# %%
data_centre_good
# Out:
#        total_area  last_price  floor  rooms  ceiling_height  \
# 24           97.2     6500000      1      2             NaN
# 61           74.0     7990000      4      2             NaN
# 99           90.0     9600000      2      4             NaN
# 137          85.1    13310800      5      2            2.70
# 138          40.0     4800000      2      2             NaN
# ...           ...         ...    ...    ...             ...
# 23602        73.0     8700000      4      3            2.65
# 23609        64.3     7280000     10      2             NaN
# 23644        62.5     4990000      4      2            2.70
# 23665        47.0     4250000      1      1             NaN
# 23691        72.9     9470000      7      2            2.75
#
#        cityCenters_nearest first_day_exposition  year  month  day_of_week
# 24                  2336.0           2015-10-31  2015     10            5
# 61                  4288.0           2017-08-24  2017      8            3
# ...

# %% [markdown]
# #### Анализ территории по параметрам: площадь, цена, число комнат, высота потолков.

# %%
list_of_vars3 = ['total_area','rooms','cityCenters_nearest','ceiling_height']

# %%
for var in list_of_vars3:
    ax = data_centre_good.plot(x = var, y = 'last_price',style = 'o', title = 'Зависимость last_price от '+var,alpha = 0.3)
    ax.set_ylabel("last_price")
    plt.show()

# %% [markdown]
# #### Анализ факторов, которые влияют на стоимость квартиры

# %%
pearsoncorr2 = data_centre_good.corr()
plt.figure(figsize = (20,10))
sb.heatmap(pearsoncorr2,annot = True,linewidths=.5,cmap="YlGnBu")

# %% [markdown]
# #### Сравнение между городом и его центром

# %% [markdown]
# ##### Центр города

# %% [markdown]
# По графикам видно:
#  - зависимость между ценой и общей площадью есть, коэффициент корреляции Пирсона = 0.77;
#  - зависимость между ценой и количеством комнат есть, коэффициент корреляции Пирсона = 0.51;
#  - зависимости между ценой и расстоянием до центра нет, коэффициент корреляции Пирсона =   -0.004;
#  - зависимости между ценой и этажами практически нет, коэффициент корреляции Пирсона = 0.21;
#  - зависимости между ценой и высотой потолка практически нет, коэффициент корреляции Пирсона = 0.13

# %% [markdown]
# ##### Город

# %%
spb_corr = spb[['last_price', 'total_area',
                 'cityCenters_nearest', 'floor', 'ceiling_height', 
                'rooms', 'year','month','day_of_week']]

# %%
spb_corr
# Out:
#        last_price  total_area  cityCenters_nearest  floor  ceiling_height  \
# 0        13000000      108.00              16028.0      8            2.70
# 2         5196000       56.00              13933.0      4             NaN
# 4        10000000      100.00               8098.0     13            3.03
# 7         7915000       71.60              11634.0     22             NaN
# 9         5400000       61.00              15008.0      7            2.50
# ...           ...         ...                  ...    ...             ...
# 23688     9200000      101.00              14428.0     12            3.05
# 23689     3550000       35.30              16081.0      4            2.86
# 23690     5500000       52.00               6263.0      2             NaN
# 23691     9470000       72.90               4489.0      7            2.75
# 23697    11475000       76.75              10364.0     12            3.00
#
#        rooms  year  month  day_of_week
# 0          3  2019      3            3
# ...

# %%
pearsoncorr_spb = spb_corr.corr()
plt.figure(figsize = (20,10))
sb.heatmap(pearsoncorr_spb,annot = True,linewidths=.5,cmap="YlGnBu")

# %% [markdown]
# - зависимость между ценой и общей площадью есть, коэффициент корреляции Пирсона = 0.84;
# - зависимость между ценой и количеством комнат есть, коэффициент корреляции Пирсона = 0.79;
# - зависимость между ценой и расстоянием до центра есть, коэффициент корреляции Пирсона = -0.31;
# - зависимости между ценой и этажами практически нет, коэффициент корреляции Пирсона = 0.09;
# - зависимость между ценой и высотой потолка есть, коэффициент корреляции Пирсона = 0.44.

# %% [markdown]
# #### Вывод

# %% [markdown]
# Если сравнивать зависимости между ценой и общей площадью/количеством комнат, то они практические не отличаются. А вот зависимость между ценой и высотой потолка/этажом сильно отличается

# %%
list_of_vars3 = ['total_area','rooms','cityCenters_nearest',
                 'ceiling_height','floor','year']

# %%
for var in list_of_vars3:
    fig, (ax1) = plt.subplots(1,figsize=(6,6))
    ax1.scatter(spb[var],spb['last_price'],alpha = 0.5,label = 'По всему Санкт-Петербургу')
    ax1.grid(True)
    ax1.scatter(data_centre_good[var],data_centre_good['last_price'],alpha = 0.5,label = 'По центру Санкт-Петербурга')
    ax1.set_ylabel("last_price")
    ax1.set_xlabel(var)
    ax1.legend()
    plt.show()

# %% [markdown]
# Объединил весь город и центр города, по ним можно много интересных выводов сделать. Если взять высоту потолков, то видно, что в центре высота потолков в основном 3 метра

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Наша задача — установить параметры. Это позволило построить автоматизированную систему. Мы проделали большую работу:
#  - предобработали данные;
#  - вычислили и добавили новые параметры в таблицу;
#  - провели исследовательский анализ данных и ответили на несколько вопросов.
#
# Как показал анализ данных:
#  - На цену квартиры больше всего влияют следующие параметры:
#   - общая площадь, коэффициент корреляции Пирсона = 0.72;
#   - количество комнат, коэффициент корреляции Пирсона = 0.47;
#   - расстояние до центра, коэффициент корреляции Пирсона = -0.31;
#
#  - самая низкая стоимость за квадратный метр в Выборге - 57 752 рублей, а самая высокая в Санкт-Петербурге - 103 596 рублей;
#  - Радиус центра Санкт-Петербурга - 5 км;
#  - На цену квартиры в центре больше всего влияют следующие параметры:
#   - общая площадь, коэффициент корреляции Пирсона = 0.75
#   - количество комнат, коэффициент корреляции Пирсона = 0.56;
#   - высота потолка, коэффициент корреляции Пирсона = 0.21
